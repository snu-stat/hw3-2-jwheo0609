# %% [markdown]
# #
#
# # 숙제 3
#
# 이름: \[허종원\] 학번: \[2025-26589\]
#
# 이 숙제의 상세 분석 결과는 아래 링크에서 확인하실 수 있습니다.
#
# - [분석 리포트 (HTML)](./hw03.html)
# - [주피터 노트북
#   (ipynb)](https://mybinder.org/v2/gh/snu-stat/hw3-2-jwheo0609/gh-pages?labpath=hw03.ipynb)
